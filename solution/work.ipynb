# %% [markdown]
# # Creación de csv para ingesta de base de datos

# %%
import pandas as pd
from datetime import datetime, timedelta
import random
import numpy as np
import warnings
warnings.filterwarnings("ignore")
today = datetime.now()

# %% [markdown]
# ### Creación de csv de clientes

# %%
data = pd.read_csv("CUSTOMER.csv")
fecha_actual = datetime.now()
z_code = pd.read_csv("ZIPCODES.csv", encoding='latin')
codes = set(z_code['Country'].dropna())
data['birthday']=pd.to_datetime(data['birthday'])
data['Edad'] = fecha_actual.year - data['birthday'].dt.year
data['birthday'] = data['birthday'].dt.strftime('%Y-%m-%d')
data['zipcode'] = np.random.choice(list(codes), size=len(data))
data.to_csv('customer_data.csv')
data
# Out:
#        id    surname    birthday               address  phone_number  Edad  \
# 0       1      Caryl  1996-01-27     2 Farmco Crossing  595-642-5891    28
# 1       2  Guglielmo  1996-10-06       86943 Chive Way  538-266-7527    28
# 2       3  Aprilette  1995-01-16      697 Sachs Avenue  859-366-3566    29
# 3       4     Dorree  1998-12-30       33 Mayfield Way  883-884-4505    26
# 4       5     Darbee  1998-05-17    969 Loeprich Trail  725-355-0696    26
# ..    ...        ...         ...                   ...           ...   ...
# 995   996   Humphrey  1997-10-05    1486 Eastwood Park  345-152-7275    27
# 996   997       Vale  1998-03-16     92 Pearson Circle  559-809-1094    26
# 997   998       Chan  1997-10-27    5731 Hansons Court  429-541-9910    27
# 998   999     Mannie  1996-01-17    71509 Carioca Park  196-985-4712    28
# 999  1000    Rancell  1998-04-24  2796 Crest Line Pass  183-870-9208    26
#
#      zipcode
# 0    51640.0
# 1    51730.0
# 2    51676.0
# 3    51760.0
# 4    51800.0
# ..       ...
# 995  51614.0
# 996  51723.0
# 997  51620.0
# 998  51773.0
# 999  51693.0
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Creación de csv de contratos

# %%
data = pd.read_csv("Contracts.csv")
data
# Out:
#       id Contract_start Contract_end  total_amount
# 0    362     28/01/2023   28/02/2021         20474
# 1    476     02/08/2024   11/05/2018         25062
# 2    318     02/12/2015   01/05/2021         24979
# 3    405     13/12/2020   13/03/2023         19372
# 4    454     30/03/2022   31/10/2019         89682
# ..   ...            ...          ...           ...
# 995  326     15/08/2016   26/11/2024         68398
# 996   18     18/05/2024   31/07/2021         45222
# 997  454     18/12/2019   08/11/2022         46674
# 998  272     30/11/2018   22/12/2019         17708
# 999  441     30/11/2023   22/10/2022         25515
#
# [1000 rows x 4 columns]

# %%
#Ajustar formato de columnas de tiempo
def day_transform(row):
    row['Contract_start']=row['Contract_start'].replace('-','/')
    try:
        timeN = pd.to_datetime(row['Contract_start'])
    except:
        row['Contract_start']=row['Contract_start'].replace(row['Contract_start'][:2],'01')
        timeN = pd.to_datetime(row['Contract_start'])
    return timeN
def endday_transform(row):
    row['Contract_end']=row['Contract_end'].replace('-','/')
    try:
        timeN = pd.to_datetime(row['Contract_end'])
    except:
        row['Contract_end']=row['Contract_end'].replace(row['Contract_end'][:2],'01')
        timeN = pd.to_datetime(row['Contract_end'])
    return timeN
data['Contract_start']= data.apply(day_transform, axis=1)
data['Contract_end']= data.apply(endday_transform, axis=1)
data
# Out:
#       id Contract_start Contract_end  total_amount
# 0    362     2023-01-28   2021-02-28         20474
# 1    476     2024-02-08   2018-11-05         25062
# 2    318     2015-02-12   2021-01-05         24979
# 3    405     2020-12-13   2023-03-13         19372
# 4    454     2022-03-30   2019-10-31         89682
# ..   ...            ...          ...           ...
# 995  326     2016-08-15   2024-11-26         68398
# 996   18     2024-05-18   2021-07-31         45222
# 997  454     2019-12-18   2022-08-11         46674
# 998  272     2018-11-30   2019-12-22         17708
# 999  441     2023-11-30   2022-10-22         25515
#
# [1000 rows x 4 columns]

# %%
#Acomodar fechas de inicio y fin de los contratos
def swap_values(row):
    if row['Contract_end'] < row['Contract_start']:
        temp = row['Contract_start']
        row['Contract_start'] = row['Contract_end']
        row['Contract_end'] = temp
    return row

data = data.apply(swap_values, axis=1)

# %%
data
# Out:
#       id Contract_start Contract_end  total_amount
# 0    362     2021-02-28   2023-01-28         20474
# 1    476     2018-11-05   2024-02-08         25062
# 2    318     2015-02-12   2021-01-05         24979
# 3    405     2020-12-13   2023-03-13         19372
# 4    454     2019-10-31   2022-03-30         89682
# ..   ...            ...          ...           ...
# 995  326     2016-08-15   2024-11-26         68398
# 996   18     2021-07-31   2024-05-18         45222
# 997  454     2019-12-18   2022-08-11         46674
# 998  272     2018-11-30   2019-12-22         17708
# 999  441     2022-10-22   2023-11-30         25515
#
# [1000 rows x 4 columns]

# %%
def get_days(row):
    d=max(1, round(row['days_duration'] / 31))
    return d
data['days_duration'] = (data['Contract_end'] - data['Contract_start']).dt.days

payment_frequency = 'M'

data['payment_freq'] = data.apply(get_days, axis=1)

data['payment_amount'] = data['total_amount'] / data['payment_freq']
data.to_csv('LOAN_DATA.csv', index=False)
data
# Out:
# id                                362
# Contract_start    2021-02-28 00:00:00
# Contract_end      2023-01-28 00:00:00
# total_amount                    20474
# days_duration                     699
# Name: 0, dtype: object
# id                                476
# Contract_start    2018-11-05 00:00:00
# Contract_end      2024-02-08 00:00:00
# total_amount                    25062
# days_duration                    1921
# Name: 1, dtype: object
# id                                318
# Contract_start    2015-02-12 00:00:00
# Contract_end      2021-01-05 00:00:00
# total_amount                    24979
# days_duration                    2154
# Name: 2, dtype: object
# id                                405
# Contract_start    2020-12-13 00:00:00
# Contract_end      2023-03-13 00:00:00
# total_amount                    19372
# days_duration                     820
# Name: 3, dtype: object
# id                                454
# Contract_start    2019-10-31 00:00:00
# Contract_end      2022-03-30 00:00:00
# total_amount                    89682
# days_duration                     881
# Name: 4, dtype: object
# id                                271
# Contract_start    2015-08-31 00:00:00
# Contract_end      2023-02-12 00:00:00
# total_amount                    59522
# days_duration                    2722
# Name: 5, dtype: object
# id                                482
# Contract_start    2021-12-30 00:00:00
# Contract_end      2022-08-12 00:00:00
# total_amount                    40272
# days_duration                     225
# Name: 6, dtype: object
# id                                450
# Contract_start    2020-10-31 00:00:00
# Contract_end      2021-12-12 00:00:00
# total_amount                    25696
# days_duration                     407
# Name: 7, dtype: object
# id                                276
# Contract_start    2021-10-22 00:00:00
# Contract_end      2024-01-02 00:00:00
# total_amount                    71083
# days_duration                     802
# Name: 8, dtype: object
# id                                129
# Contract_start    2022-10-25 00:00:00
# Contract_end      2024-10-31 00:00:00
# total_amount                    41311
# days_duration                     737
# Name: 9, dtype: object
# id                                166
# Contract_start    2017-10-16 00:00:00
# Contract_end      2020-11-19 00:00:00
# total_amount                    95673
# days_duration                    1130
# Name: 10, dtype: object
# id                                268
# Contract_start    2019-11-26 00:00:00
# Contract_end      2021-05-28 00:00:00
# total_amount                     8881
# days_duration                     549
# Name: 11, dtype: object
# id                                167
# Contract_start    2023-08-22 00:00:00
# Contract_end      2024-11-09 00:00:00
# total_amount                    48732
# days_duration                     445
# Name: 12, dtype: object
# id                                186
# Contract_start    2019-10-03 00:00:00
# Contract_end      2023-05-31 00:00:00
# total_amount                    14981
# days_duration                    1336
# Name: 13, dtype: object
# id                                315
# Contract_start    2019-01-07 00:00:00
# Contract_end      2020-09-30 00:00:00
# total_amount                    35764
# days_duration                     632
# Name: 14, dtype: object
# id                                322
# Contract_start    2016-12-25 00:00:00
# Contract_end      2024-02-15 00:00:00
# total_amount                    25677
# days_duration                    2608
# Name: 15, dtype: object
# id                                103
# Contract_start    2019-05-13 00:00:00
# Contract_end      2020-07-11 00:00:00
# total_amount                    69653
# days_duration                     425
# Name: 16, dtype: object
# id                                267
# Contract_start    2015-10-01 00:00:00
# Contract_end      2018-10-24 00:00:00
# total_amount                    77532
# days_duration                    1119
# Name: 17, dtype: object
# id                                447
# Contract_start    2020-07-10 00:00:00
# Contract_end      2022-12-19 00:00:00
# total_amount                     5515
# days_duration                     892
# Name: 18, dtype: object
# id                                122
# Contract_start    2024-02-01 00:00:00
# Contract_end      2024-03-03 00:00:00
# total_amount                    73436
# days_duration                      31
# Name: 19, dtype: object
# id                                 11
# Contract_start    2016-01-14 00:00:00
# Contract_end      2023-12-06 00:00:00
# total_amount                    63918
# days_duration                    2883
# Name: 20, dtype: object
# id                                316
# Contract_start    2022-10-30 00:00:00
# Contract_end      2023-07-20 00:00:00
# total_amount                    88438
# days_duration                     263
# Name: 21, dtype: object
# id                                 36
# Contract_start    2019-11-30 00:00:00
# Contract_end      2020-05-31 00:00:00
# total_amount                    49017
# days_duration                     183
# Name: 22, dtype: object
# id                                 90
# Contract_start    2018-06-05 00:00:00
# Contract_end      2024-08-31 00:00:00
# total_amount                    98585
# days_duration                    2279
# Name: 23, dtype: object
# id                                 32
# Contract_start    2018-11-30 00:00:00
# Contract_end      2022-01-03 00:00:00
# total_amount                     2889
# days_duration                    1130
# Name: 24, dtype: object
# id                                492
# Contract_start    2020-02-25 00:00:00
# Contract_end      2023-12-06 00:00:00
# total_amount                    49302
# days_duration                    1380
# Name: 25, dtype: object
# id                                441
# Contract_start    2016-10-31 00:00:00
# Contract_end      2023-11-14 00:00:00
# total_amount                    53032
# days_duration                    2570
# Name: 26, dtype: object
# id                                459
# Contract_start    2022-11-16 00:00:00
# Contract_end      2023-12-31 00:00:00
# total_amount                    66292
# days_duration                     410
# Name: 27, dtype: object
# id                                453
# Contract_start    2017-09-02 00:00:00
# Contract_end      2021-11-24 00:00:00
# total_amount                    18424
# days_duration                    1544
# Name: 28, dtype: object
# id                                 66
# Contract_start    2018-02-18 00:00:00
# Contract_end      2020-11-11 00:00:00
# total_amount                    64757
# days_duration                     997
# Name: 29, dtype: object
# id                                295
# Contract_start    2019-07-26 00:00:00
# Contract_end      2023-12-31 00:00:00
# total_amount                    20690
# days_duration                    1619
# Name: 30, dtype: object
# id                                232
# Contract_start    2020-04-29 00:00:00
# Contract_end      2021-01-11 00:00:00
# total_amount                    89710
# days_duration                     257
# Name: 31, dtype: object
# id                                220
# Contract_start    2020-08-11 00:00:00
# Contract_end      2024-01-04 00:00:00
# total_amount                    27851
# days_duration                    1241
# Name: 32, dtype: object
# id                                318
# Contract_start    2018-12-24 00:00:00
# Contract_end      2021-10-21 00:00:00
# total_amount                    85106
# days_duration                    1032
# Name: 33, dtype: object
# id                                363
# Contract_start    2018-07-18 00:00:00
# Contract_end      2022-06-25 00:00:00
# total_amount                    51876
# days_duration                    1438
# Name: 34, dtype: object
# id                                 56
# Contract_start    2018-11-16 00:00:00
# Contract_end      2023-10-26 00:00:00
# total_amount                    59268
# days_duration                    1805
# Name: 35, dtype: object
# id                                108
# Contract_start    2018-05-23 00:00:00
# Contract_end      2021-11-30 00:00:00
# total_amount                    19485
# days_duration                    1287
# Name: 36, dtype: object
# id                                343
# Contract_start    2021-08-30 00:00:00
# Contract_end      2024-10-16 00:00:00
# total_amount                    15800
# days_duration                    1143
# Name: 37, dtype: object
# id                                237
# Contract_start    2019-04-12 00:00:00
# Contract_end      2024-04-08 00:00:00
# total_amount                    52537
# days_duration                    1823
# Name: 38, dtype: object
# id                                  3
# Contract_start    2016-08-24 00:00:00
# Contract_end      2021-12-31 00:00:00
# total_amount                    35587
# days_duration                    1955
# Name: 39, dtype: object
# id                                242
# Contract_start    2015-02-03 00:00:00
# Contract_end      2023-01-11 00:00:00
# total_amount                    90297
# days_duration                    2899
# Name: 40, dtype: object
# id                                216
# Contract_start    2018-10-18 00:00:00
# Contract_end      2020-10-17 00:00:00
# total_amount                    42357
# days_duration                     730
# Name: 41, dtype: object
# id                                329
# Contract_start    2017-10-31 00:00:00
# Contract_end      2023-01-02 00:00:00
# total_amount                    90385
# days_duration                    1889
# Name: 42, dtype: object
# id                                406
# Contract_start    2015-03-08 00:00:00
# Contract_end      2024-02-04 00:00:00
# total_amount                    67826
# days_duration                    3255
# Name: 43, dtype: object
# id                                 76
# Contract_start    2019-10-13 00:00:00
# Contract_end      2022-10-27 00:00:00
# total_amount                     1073
# days_duration                    1110
# Name: 44, dtype: object
# id                                327
# Contract_start    2019-04-26 00:00:00
# Contract_end      2023-12-10 00:00:00
# total_amount                    18269
# days_duration                    1689
# Name: 45, dtype: object
# id                                153
# Contract_start    2017-12-30 00:00:00
# Contract_end      2022-12-31 00:00:00
# total_amount                    57117
# days_duration                    1827
# Name: 46, dtype: object
# id                                291
# Contract_start    2016-12-31 00:00:00
# Contract_end      2022-01-30 00:00:00
# total_amount                    42679
# days_duration                    1856
# Name: 47, dtype: object
# id                                283
# Contract_start    2018-01-11 00:00:00
# Contract_end      2019-01-04 00:00:00
# total_amount                    97251
# days_duration                     358
# Name: 48, dtype: object
# id                                239
# Contract_start    2018-06-12 00:00:00
# Contract_end      2020-10-18 00:00:00
# total_amount                    13285
# days_duration                     859
# Name: 49, dtype: object
# id                                252
# Contract_start    2022-04-02 00:00:00
# Contract_end      2024-10-18 00:00:00
# total_amount                    59949
# days_duration                     930
# Name: 50, dtype: object
# id                                333
# Contract_start    2020-02-27 00:00:00
# Contract_end      2022-01-10 00:00:00
# total_amount                    93626
# days_duration                     683
# Name: 51, dtype: object
# id                                207
# Contract_start    2019-10-29 00:00:00
# Contract_end      2021-10-27 00:00:00
# total_amount                    19030
# days_duration                     729
# Name: 52, dtype: object
# id                                229
# Contract_start    2018-05-10 00:00:00
# Contract_end      2021-11-07 00:00:00
# total_amount                    15289
# days_duration                    1277
# Name: 53, dtype: object
# id                                 99
# Contract_start    2015-11-16 00:00:00
# Contract_end      2020-10-16 00:00:00
# total_amount                    46698
# days_duration                    1796
# Name: 54, dtype: object
# id                                342
# Contract_start    2018-12-30 00:00:00
# Contract_end      2021-12-16 00:00:00
# total_amount                    85740
# days_duration                    1082
# Name: 55, dtype: object
# id                                392
# Contract_start    2024-01-24 00:00:00
# Contract_end      2024-12-10 00:00:00
# total_amount                    52573
# days_duration                     321
# Name: 56, dtype: object
# id                                124
# Contract_start    2021-05-03 00:00:00
# Contract_end      2024-04-28 00:00:00
# total_amount                     5156
# days_duration                    1091
# Name: 57, dtype: object
# id                                323
# Contract_start    2015-01-13 00:00:00
# Contract_end      2020-06-11 00:00:00
# total_amount                    83681
# days_duration                    1976
# Name: 58, dtype: object
# id                                113
# Contract_start    2020-02-23 00:00:00
# Contract_end      2023-10-31 00:00:00
# total_amount                     7463
# days_duration                    1346
# Name: 59, dtype: object
# id                                437
# Contract_start    2017-05-06 00:00:00
# Contract_end      2021-03-22 00:00:00
# total_amount                     9208
# days_duration                    1416
# Name: 60, dtype: object
# id                                473
# Contract_start    2021-01-04 00:00:00
# Contract_end      2024-10-12 00:00:00
# total_amount                    34691
# days_duration                    1377
# Name: 61, dtype: object
# id                                207
# Contract_start    2018-10-28 00:00:00
# Contract_end      2022-06-13 00:00:00
# total_amount                    24315
# days_duration                    1324
# Name: 62, dtype: object
# id                                367
# Contract_start    2021-08-27 00:00:00
# Contract_end      2023-06-12 00:00:00
# total_amount                    36908
# days_duration                     654
# Name: 63, dtype: object
# id                                135
# Contract_start    2021-01-03 00:00:00
# Contract_end      2024-06-11 00:00:00
# total_amount                    34227
# days_duration                    1255
# Name: 64, dtype: object
# id                                 96
# Contract_start    2018-04-25 00:00:00
# Contract_end      2023-03-05 00:00:00
# total_amount                    54371
# days_duration                    1775
# Name: 65, dtype: object
# id                                 22
# Contract_start    2016-12-13 00:00:00
# Contract_end      2023-05-13 00:00:00
# total_amount                     1696
# days_duration                    2342
# Name: 66, dtype: object
# id                                481
# Contract_start    2019-06-10 00:00:00
# Contract_end      2022-10-16 00:00:00
# total_amount                    49736
# days_duration                    1224
# Name: 67, dtype: object
# id                                326
# Contract_start    2019-01-11 00:00:00
# Contract_end      2024-02-06 00:00:00
# total_amount                    34591
# days_duration                    1852
# Name: 68, dtype: object
# id                                250
# Contract_start    2016-11-22 00:00:00
# Contract_end      2022-12-19 00:00:00
# total_amount                    87410
# days_duration                    2218
# Name: 69, dtype: object
# id                                213
# Contract_start    2020-12-08 00:00:00
# Contract_end      2023-11-08 00:00:00
# total_amount                    47830
# days_duration                    1065
# Name: 70, dtype: object
# id                                295
# Contract_start    2020-10-31 00:00:00
# Contract_end      2024-09-09 00:00:00
# total_amount                    86311
# days_duration                    1409
# Name: 71, dtype: object
# id                                135
# Contract_start    2022-07-10 00:00:00
# Contract_end      2024-03-31 00:00:00
# total_amount                    66844
# days_duration                     630
# Name: 72, dtype: object
# id                                417
# Contract_start    2022-02-11 00:00:00
# Contract_end      2023-07-03 00:00:00
# total_amount                     5026
# days_duration                     507
# Name: 73, dtype: object
# id                                262
# Contract_start    2022-03-11 00:00:00
# Contract_end      2023-08-23 00:00:00
# total_amount                    61263
# days_duration                     530
# Name: 74, dtype: object
# id                                325
# Contract_start    2019-08-31 00:00:00
# Contract_end      2022-12-31 00:00:00
# total_amount                    54598
# days_duration                    1218
# Name: 75, dtype: object
# id                                300
# Contract_start    2016-02-16 00:00:00
# Contract_end      2018-10-30 00:00:00
# total_amount                     7603
# days_duration                     987
# Name: 76, dtype: object
# id                                290
# Contract_start    2023-07-31 00:00:00
# Contract_end      2024-12-30 00:00:00
# total_amount                    83345
# days_duration                     518
# Name: 77, dtype: object
# id                                332
# Contract_start    2017-08-08 00:00:00
# Contract_end      2019-10-30 00:00:00
# total_amount                    81621
# days_duration                     813
# Name: 78, dtype: object
# id                                253
# Contract_start    2022-12-30 00:00:00
# Contract_end      2023-10-31 00:00:00
# total_amount                    19442
# days_duration                     305
# Name: 79, dtype: object
# id                                 72
# Contract_start    2018-10-21 00:00:00
# Contract_end      2020-10-20 00:00:00
# total_amount                    46786
# days_duration                     730
# Name: 80, dtype: object
# id                                440
# Contract_start    2018-07-02 00:00:00
# Contract_end      2018-11-18 00:00:00
# total_amount                    33775
# days_duration                     139
# Name: 81, dtype: object
# id                                347
# Contract_start    2021-04-22 00:00:00
# Contract_end      2022-11-05 00:00:00
# total_amount                    92850
# days_duration                     562
# Name: 82, dtype: object
# id                                 81
# Contract_start    2019-12-30 00:00:00
# Contract_end      2022-06-06 00:00:00
# total_amount                    86902
# days_duration                     889
# Name: 83, dtype: object
# id                                182
# Contract_start    2020-05-29 00:00:00
# Contract_end      2023-09-10 00:00:00
# total_amount                    44382
# days_duration                    1199
# Name: 84, dtype: object
# id                                211
# Contract_start    2021-05-11 00:00:00
# Contract_end      2024-06-12 00:00:00
# total_amount                    24337
# days_duration                    1128
# Name: 85, dtype: object
# id                                303
# Contract_start    2018-08-12 00:00:00
# Contract_end      2022-04-30 00:00:00
# total_amount                    65592
# days_duration                    1357
# Name: 86, dtype: object
# id                                251
# Contract_start    2019-10-22 00:00:00
# Contract_end      2021-12-21 00:00:00
# total_amount                    61495
# days_duration                     791
# Name: 87, dtype: object
# id                                337
# Contract_start    2016-07-31 00:00:00
# Contract_end      2020-10-16 00:00:00
# total_amount                    40780
# days_duration                    1538
# Name: 88, dtype: object
# id                                131
# Contract_start    2016-10-30 00:00:00
# Contract_end      2018-10-10 00:00:00
# total_amount                    87644
# days_duration                     710
# Name: 89, dtype: object
# id                                404
# Contract_start    2018-04-20 00:00:00
# Contract_end      2023-11-19 00:00:00
# total_amount                    63575
# days_duration                    2039
# Name: 90, dtype: object
# id                                231
# Contract_start    2019-12-31 00:00:00
# Contract_end      2022-08-11 00:00:00
# total_amount                    17138
# days_duration                     954
# Name: 91, dtype: object
# id                                313
# Contract_start    2020-12-28 00:00:00
# Contract_end      2023-09-21 00:00:00
# total_amount                    37208
# days_duration                     997
# Name: 92, dtype: object
# id                                 28
# Contract_start    2015-09-11 00:00:00
# Contract_end      2018-07-03 00:00:00
# total_amount                     4343
# days_duration                    1026
# Name: 93, dtype: object
# id                                337
# Contract_start    2024-11-08 00:00:00
# Contract_end      2024-12-12 00:00:00
# total_amount                    65762
# days_duration                      34
# Name: 94, dtype: object
# id                                486
# Contract_start    2020-05-30 00:00:00
# Contract_end      2021-08-25 00:00:00
# total_amount                     3626
# days_duration                     452
# Name: 95, dtype: object
# id                                458
# Contract_start    2017-02-13 00:00:00
# Contract_end      2021-02-21 00:00:00
# total_amount                    99467
# days_duration                    1469
# Name: 96, dtype: object
# id                                178
# Contract_start    2017-05-25 00:00:00
# Contract_end      2023-05-10 00:00:00
# total_amount                    78910
# days_duration                    2176
# Name: 97, dtype: object
# id                                351
# Contract_start    2021-04-25 00:00:00
# Contract_end      2021-04-30 00:00:00
# total_amount                    33553
# days_duration                       5
# Name: 98, dtype: object
# id                                348
# Contract_start    2017-12-03 00:00:00
# Contract_end      2019-01-20 00:00:00
# total_amount                    24757
# days_duration                     413
# Name: 99, dtype: object
# id                                 88
# Contract_start    2022-09-21 00:00:00
# Contract_end      2023-11-24 00:00:00
# total_amount                    73413
# days_duration                     429
# Name: 100, dtype: object
# id                                104
# Contract_start    2018-05-30 00:00:00
# Contract_end      2021-04-07 00:00:00
# total_amount                    26091
# days_duration                    1043
# Name: 101, dtype: object
# id                                330
# Contract_start    2019-12-25 00:00:00
# Contract_end      2020-11-25 00:00:00
# total_amount                    38899
# days_duration                     336
# Name: 102, dtype: object
# id                                 37
# Contract_start    2023-12-02 00:00:00
# Contract_end      2024-10-30 00:00:00
# total_amount                    41777
# days_duration                     333
# Name: 103, dtype: object
# id                                 51
# Contract_start    2015-10-30 00:00:00
# Contract_end      2024-05-09 00:00:00
# total_amount                    48993
# days_duration                    3114
# Name: 104, dtype: object
# id                                408
# Contract_start    2020-05-11 00:00:00
# Contract_end      2024-09-10 00:00:00
# total_amount                    77143
# days_duration                    1583
# Name: 105, dtype: object
# id                                363
# Contract_start    2015-02-11 00:00:00
# Contract_end      2019-01-11 00:00:00
# total_amount                    87404
# days_duration                    1430
# Name: 106, dtype: object
# id                                255
# Contract_start    2022-01-09 00:00:00
# Contract_end      2023-10-09 00:00:00
# total_amount                    36584
# days_duration                     638
# Name: 107, dtype: object
# id                                111
# Contract_start    2017-03-28 00:00:00
# Contract_end      2022-10-22 00:00:00
# total_amount                    46496
# days_duration                    2034
# Name: 108, dtype: object
# id                                 59
# Contract_start    2023-08-04 00:00:00
# Contract_end      2023-11-30 00:00:00
# total_amount                    23315
# days_duration                     118
# Name: 109, dtype: object
# id                                447
# Contract_start    2019-01-11 00:00:00
# Contract_end      2022-01-02 00:00:00
# total_amount                    46078
# days_duration                    1087
# Name: 110, dtype: object
# id                                367
# Contract_start    2017-07-05 00:00:00
# Contract_end      2019-04-05 00:00:00
# total_amount                    23168
# days_duration                     639
# Name: 111, dtype: object
# id                                243
# Contract_start    2018-09-10 00:00:00
# Contract_end      2018-10-30 00:00:00
# total_amount                    34230
# days_duration                      50
# Name: 112, dtype: object
# id                                284
# Contract_start    2020-10-31 00:00:00
# Contract_end      2022-12-14 00:00:00
# total_amount                    23491
# days_duration                     774
# Name: 113, dtype: object
# id                                 18
# Contract_start    2022-08-31 00:00:00
# Contract_end      2024-09-05 00:00:00
# total_amount                    92013
# days_duration                     736
# Name: 114, dtype: object
# id                                225
# Contract_start    2022-12-31 00:00:00
# Contract_end      2023-10-13 00:00:00
# total_amount                    94184
# days_duration                     286
# Name: 115, dtype: object
# id                                 28
# Contract_start    2021-08-31 00:00:00
# Contract_end      2021-10-20 00:00:00
# total_amount                    45567
# days_duration                      50
# Name: 116, dtype: object
# id                                341
# Contract_start    2017-09-17 00:00:00
# Contract_end      2024-11-16 00:00:00
# total_amount                    15937
# days_duration                    2617
# Name: 117, dtype: object
# id                                248
# Contract_start    2016-11-12 00:00:00
# Contract_end      2019-08-30 00:00:00
# total_amount                    28086
# days_duration                    1021
# Name: 118, dtype: object
# id                                 82
# Contract_start    2019-11-30 00:00:00
# Contract_end      2022-12-13 00:00:00
# total_amount                    37092
# days_duration                    1109
# Name: 119, dtype: object
# id                                389
# Contract_start    2018-08-10 00:00:00
# Contract_end      2024-05-11 00:00:00
# total_amount                    27865
# days_duration                    2101
# Name: 120, dtype: object
# id                                274
# Contract_start    2018-04-15 00:00:00
# Contract_end      2019-01-09 00:00:00
# total_amount                     9545
# days_duration                     269
# Name: 121, dtype: object
# id                                210
# Contract_start    2023-10-24 00:00:00
# Contract_end      2024-09-17 00:00:00
# total_amount                    17700
# days_duration                     329
# Name: 122, dtype: object
# id                                332
# Contract_start    2019-03-30 00:00:00
# Contract_end      2021-01-02 00:00:00
# total_amount                    26614
# days_duration                     644
# Name: 123, dtype: object
# id                                 85
# Contract_start    2023-11-07 00:00:00
# Contract_end      2024-01-18 00:00:00
# total_amount                    80287
# days_duration                      72
# Name: 124, dtype: object
# id                                411
# Contract_start    2020-07-07 00:00:00
# Contract_end      2021-12-28 00:00:00
# total_amount                    32595
# days_duration                     539
# Name: 125, dtype: object
# id                                125
# Contract_start    2018-11-10 00:00:00
# Contract_end      2023-10-26 00:00:00
# total_amount                    64437
# days_duration                    1811
# Name: 126, dtype: object
# id                                 32
# Contract_start    2018-12-30 00:00:00
# Contract_end      2020-12-31 00:00:00
# total_amount                    63216
# days_duration                     732
# Name: 127, dtype: object
# id                                192
# Contract_start    2017-01-29 00:00:00
# Contract_end      2022-12-30 00:00:00
# total_amount                    50056
# days_duration                    2161
# Name: 128, dtype: object
# id                                 66
# Contract_start    2017-10-30 00:00:00
# Contract_end      2021-04-18 00:00:00
# total_amount                    11381
# days_duration                    1266
# Name: 129, dtype: object
# id                                229
# Contract_start    2015-03-05 00:00:00
# Contract_end      2024-10-15 00:00:00
# total_amount                    72450
# days_duration                    3512
# Name: 130, dtype: object
# id                                126
# Contract_start    2015-01-31 00:00:00
# Contract_end      2021-04-26 00:00:00
# total_amount                    20802
# days_duration                    2277
# Name: 131, dtype: object
# id                                319
# Contract_start    2016-11-02 00:00:00
# Contract_end      2021-08-10 00:00:00
# total_amount                    10651
# days_duration                    1742
# Name: 132, dtype: object
# id                                200
# Contract_start    2015-01-30 00:00:00
# Contract_end      2021-12-16 00:00:00
# total_amount                     4056
# days_duration                    2512
# Name: 133, dtype: object
# id                                 52
# Contract_start    2019-08-31 00:00:00
# Contract_end      2019-09-30 00:00:00
# total_amount                    55499
# days_duration                      30
# Name: 134, dtype: object
# id                                 10
# Contract_start    2018-11-06 00:00:00
# Contract_end      2021-08-31 00:00:00
# total_amount                    17941
# days_duration                    1029
# Name: 135, dtype: object
# id                                 78
# Contract_start    2015-05-07 00:00:00
# Contract_end      2019-10-16 00:00:00
# total_amount                    60278
# days_duration                    1623
# Name: 136, dtype: object
# id                                262
# Contract_start    2016-06-23 00:00:00
# Contract_end      2022-06-30 00:00:00
# total_amount                    14657
# days_duration                    2198
# Name: 137, dtype: object
# id                                  7
# Contract_start    2018-01-16 00:00:00
# Contract_end      2022-12-22 00:00:00
# total_amount                    98385
# days_duration                    1801
# Name: 138, dtype: object
# id                                140
# Contract_start    2019-10-15 00:00:00
# Contract_end      2019-12-23 00:00:00
# total_amount                    81944
# days_duration                      69
# Name: 139, dtype: object
# id                                264
# Contract_start    2019-10-31 00:00:00
# Contract_end      2024-12-20 00:00:00
# total_amount                    10303
# days_duration                    1877
# Name: 140, dtype: object
# id                                485
# Contract_start    2019-06-11 00:00:00
# Contract_end      2024-01-23 00:00:00
# total_amount                    62300
# days_duration                    1687
# Name: 141, dtype: object
# id                                118
# Contract_start    2015-09-08 00:00:00
# Contract_end      2021-04-02 00:00:00
# total_amount                    99070
# days_duration                    2033
# Name: 142, dtype: object
# id                                193
# Contract_start    2021-05-12 00:00:00
# Contract_end      2023-11-21 00:00:00
# total_amount                    25019
# days_duration                     923
# Name: 143, dtype: object
# id                                 12
# Contract_start    2015-08-07 00:00:00
# Contract_end      2024-03-31 00:00:00
# total_amount                    49651
# days_duration                    3159
# Name: 144, dtype: object
# id                                138
# Contract_start    2018-11-23 00:00:00
# Contract_end      2021-02-10 00:00:00
# total_amount                    41546
# days_duration                     810
# Name: 145, dtype: object
# id                                 54
# Contract_start    2023-10-31 00:00:00
# Contract_end      2024-11-23 00:00:00
# total_amount                    73280
# days_duration                     389
# Name: 146, dtype: object
# id                                160
# Contract_start    2018-08-16 00:00:00
# Contract_end      2023-04-02 00:00:00
# total_amount                     7256
# days_duration                    1690
# Name: 147, dtype: object
# id                                 25
# Contract_start    2016-05-31 00:00:00
# Contract_end      2018-04-16 00:00:00
# total_amount                    97139
# days_duration                     685
# Name: 148, dtype: object
# id                                275
# Contract_start    2017-11-10 00:00:00
# Contract_end      2020-10-30 00:00:00
# total_amount                    63841
# days_duration                    1085
# Name: 149, dtype: object
# id                                245
# Contract_start    2017-01-12 00:00:00
# Contract_end      2024-11-19 00:00:00
# total_amount                    78669
# days_duration                    2868
# Name: 150, dtype: object
# id                                 19
# Contract_start    2015-01-02 00:00:00
# Contract_end      2019-10-30 00:00:00
# total_amount                    31400
# days_duration                    1762
# Name: 151, dtype: object
# id                                458
# Contract_start    2018-12-30 00:00:00
# Contract_end      2019-10-31 00:00:00
# total_amount                    60006
# days_duration                     305
# Name: 152, dtype: object
# id                                338
# Contract_start    2020-10-26 00:00:00
# Contract_end      2024-05-30 00:00:00
# total_amount                    98340
# days_duration                    1312
# Name: 153, dtype: object
# id                                181
# Contract_start    2018-11-17 00:00:00
# Contract_end      2024-08-29 00:00:00
# total_amount                    30518
# days_duration                    2112
# Name: 154, dtype: object
# id                                 63
# Contract_start    2021-09-17 00:00:00
# Contract_end      2022-11-19 00:00:00
# total_amount                    81118
# days_duration                     428
# Name: 155, dtype: object
# id                                359
# Contract_start    2020-02-18 00:00:00
# Contract_end      2023-01-06 00:00:00
# total_amount                    19772
# days_duration                    1053
# Name: 156, dtype: object
# id                                278
# Contract_start    2020-08-25 00:00:00
# Contract_end      2022-10-30 00:00:00
# total_amount                    60872
# days_duration                     796
# Name: 157, dtype: object
# id                                434
# Contract_start    2021-01-23 00:00:00
# Contract_end      2024-02-11 00:00:00
# total_amount                    24567
# days_duration                    1114
# Name: 158, dtype: object
# id                                201
# Contract_start    2021-05-31 00:00:00
# Contract_end      2021-12-21 00:00:00
# total_amount                    48820
# days_duration                     204
# Name: 159, dtype: object
# id                                471
# Contract_start    2022-08-30 00:00:00
# Contract_end      2024-12-30 00:00:00
# total_amount                    89677
# days_duration                     853
# Name: 160, dtype: object
# id                                119
# Contract_start    2015-04-09 00:00:00
# Contract_end      2021-08-04 00:00:00
# total_amount                    74773
# days_duration                    2309
# Name: 161, dtype: object
# id                                130
# Contract_start    2017-01-02 00:00:00
# Contract_end      2021-08-12 00:00:00
# total_amount                    27220
# days_duration                    1683
# Name: 162, dtype: object
# id                                182
# Contract_start    2018-01-16 00:00:00
# Contract_end      2022-11-30 00:00:00
# total_amount                    47156
# days_duration                    1779
# Name: 163, dtype: object
# id                                 90
# Contract_start    2015-04-22 00:00:00
# Contract_end      2024-12-23 00:00:00
# total_amount                    55147
# days_duration                    3533
# Name: 164, dtype: object
# id                                115
# Contract_start    2022-10-24 00:00:00
# Contract_end      2023-06-12 00:00:00
# total_amount                    49957
# days_duration                     231
# Name: 165, dtype: object
# id                                475
# Contract_start    2022-04-30 00:00:00
# Contract_end      2023-12-21 00:00:00
# total_amount                    81576
# days_duration                     600
# Name: 166, dtype: object
# id                                107
# Contract_start    2022-09-28 00:00:00
# Contract_end      2022-10-11 00:00:00
# total_amount                    27795
# days_duration                      13
# Name: 167, dtype: object
# id                                251
# Contract_start    2017-01-02 00:00:00
# Contract_end      2018-01-05 00:00:00
# total_amount                    23227
# days_duration                     368
# Name: 168, dtype: object
# id                                139
# Contract_start    2016-12-22 00:00:00
# Contract_end      2020-11-14 00:00:00
# total_amount                     9179
# days_duration                    1423
# Name: 169, dtype: object
# id                                497
# Contract_start    2017-06-30 00:00:00
# Contract_end      2018-03-29 00:00:00
# total_amount                    46015
# days_duration                     272
# Name: 170, dtype: object
# id                                147
# Contract_start    2018-12-29 00:00:00
# Contract_end      2020-12-19 00:00:00
# total_amount                    52077
# days_duration                     721
# Name: 171, dtype: object
# id                                497
# Contract_start    2017-10-30 00:00:00
# Contract_end      2021-01-02 00:00:00
# total_amount                    38392
# days_duration                    1160
# Name: 172, dtype: object
# id                                 18
# Contract_start    2016-02-11 00:00:00
# Contract_end      2018-10-27 00:00:00
# total_amount                    99300
# days_duration                     989
# Name: 173, dtype: object
# id                                380
# Contract_start    2022-04-18 00:00:00
# Contract_end      2023-12-19 00:00:00
# total_amount                    42313
# days_duration                     610
# Name: 174, dtype: object
# id                                467
# Contract_start    2015-01-02 00:00:00
# Contract_end      2020-06-20 00:00:00
# total_amount                    14276
# days_duration                    1996
# Name: 175, dtype: object
# id                                 69
# Contract_start    2021-09-14 00:00:00
# Contract_end      2023-10-30 00:00:00
# total_amount                    55439
# days_duration                     776
# Name: 176, dtype: object
# id                                168
# Contract_start    2023-03-12 00:00:00
# Contract_end      2023-07-28 00:00:00
# total_amount                    79101
# days_duration                     138
# Name: 177, dtype: object
# id                                106
# Contract_start    2017-01-31 00:00:00
# Contract_end      2019-01-10 00:00:00
# total_amount                    30864
# days_duration                     709
# Name: 178, dtype: object
# id                                252
# Contract_start    2019-05-30 00:00:00
# Contract_end      2023-04-08 00:00:00
# total_amount                    89082
# days_duration                    1409
# Name: 179, dtype: object
# id                                320
# Contract_start    2019-11-09 00:00:00
# Contract_end      2023-10-30 00:00:00
# total_amount                    29305
# days_duration                    1451
# Name: 180, dtype: object
# id                                441
# Contract_start    2018-04-15 00:00:00
# Contract_end      2023-02-03 00:00:00
# total_amount                    29068
# days_duration                    1755
# Name: 181, dtype: object
# id                                149
# Contract_start    2021-10-26 00:00:00
# Contract_end      2021-11-25 00:00:00
# total_amount                    56968
# days_duration                      30
# Name: 182, dtype: object
# id                                181
# Contract_start    2017-10-14 00:00:00
# Contract_end      2018-06-30 00:00:00
# total_amount                    44791
# days_duration                     259
# Name: 183, dtype: object
# id                                362
# Contract_start    2016-01-06 00:00:00
# Contract_end      2019-10-30 00:00:00
# total_amount                    38111
# days_duration                    1393
# Name: 184, dtype: object
# id                                493
# Contract_start    2017-01-02 00:00:00
# Contract_end      2019-12-22 00:00:00
# total_amount                    18395
# days_duration                    1084
# Name: 185, dtype: object
# id                                143
# Contract_start    2020-01-01 00:00:00
# Contract_end      2024-12-16 00:00:00
# total_amount                    58422
# days_duration                    1811
# Name: 186, dtype: object
# id                                500
# Contract_start    2016-06-17 00:00:00
# Contract_end      2022-10-16 00:00:00
# total_amount                    12858
# days_duration                    2312
# Name: 187, dtype: object
# id                                287
# Contract_start    2021-12-31 00:00:00
# Contract_end      2024-12-31 00:00:00
# total_amount                    15616
# days_duration                    1096
# Name: 188, dtype: object
# id                                457
# Contract_start    2018-07-11 00:00:00
# Contract_end      2022-02-24 00:00:00
# total_amount                    60957
# days_duration                    1324
# Name: 189, dtype: object
# id                                482
# Contract_start    2015-12-09 00:00:00
# Contract_end      2021-03-27 00:00:00
# total_amount                    53694
# days_duration                    1935
# Name: 190, dtype: object
# id                                134
# Contract_start    2017-01-02 00:00:00
# Contract_end      2019-05-31 00:00:00
# total_amount                    81586
# days_duration                     879
# Name: 191, dtype: object
# id                                444
# Contract_start    2019-06-06 00:00:00
# Contract_end      2024-06-17 00:00:00
# total_amount                    14806
# days_duration                    1838
# Name: 192, dtype: object
# id                                359
# Contract_start    2022-08-31 00:00:00
# Contract_end      2022-09-23 00:00:00
# total_amount                     7722
# days_duration                      23
# Name: 193, dtype: object
# id                                161
# Contract_start    2022-07-17 00:00:00
# Contract_end      2022-08-06 00:00:00
# total_amount                    32323
# days_duration                      20
# Name: 194, dtype: object
# id                                 57
# Contract_start    2015-10-08 00:00:00
# Contract_end      2023-07-11 00:00:00
# total_amount                    98751
# days_duration                    2833
# Name: 195, dtype: object
# id                                298
# Contract_start    2018-12-26 00:00:00
# Contract_end      2023-12-31 00:00:00
# total_amount                    36158
# days_duration                    1831
# Name: 196, dtype: object
# id                                108
# Contract_start    2021-08-09 00:00:00
# Contract_end      2022-10-26 00:00:00
# total_amount                    18375
# days_duration                     443
# Name: 197, dtype: object
# id                                132
# Contract_start    2018-12-19 00:00:00
# Contract_end      2019-10-31 00:00:00
# total_amount                    95472
# days_duration                     316
# Name: 198, dtype: object
# id                                401
# Contract_start    2024-03-12 00:00:00
# Contract_end      2024-12-30 00:00:00
# total_amount                    21785
# days_duration                     293
# Name: 199, dtype: object
# id                                 50
# Contract_start    2016-12-18 00:00:00
# Contract_end      2020-11-15 00:00:00
# total_amount                    99836
# days_duration                    1428
# Name: 200, dtype: object
# id                                128
# Contract_start    2019-03-11 00:00:00
# Contract_end      2024-02-17 00:00:00
# total_amount                    82597
# days_duration                    1804
# Name: 201, dtype: object
# id                                348
# Contract_start    2015-07-15 00:00:00
# Contract_end      2024-09-02 00:00:00
# total_amount                    67238
# days_duration                    3337
# Name: 202, dtype: object
# id                                165
# Contract_start    2017-08-19 00:00:00
# Contract_end      2019-04-12 00:00:00
# total_amount                    76838
# days_duration                     601
# Name: 203, dtype: object
# id                                478
# Contract_start    2021-11-30 00:00:00
# Contract_end      2021-12-12 00:00:00
# total_amount                    87965
# days_duration                      12
# Name: 204, dtype: object
# id                                277
# Contract_start    2018-11-23 00:00:00
# Contract_end      2023-08-14 00:00:00
# total_amount                    22833
# days_duration                    1725
# Name: 205, dtype: object
# id                                172
# Contract_start    2017-11-29 00:00:00
# Contract_end      2019-01-30 00:00:00
# total_amount                    46311
# days_duration                     427
# Name: 206, dtype: object
# id                                491
# Contract_start    2021-09-30 00:00:00
# Contract_end      2021-10-11 00:00:00
# total_amount                     8163
# days_duration                      11
# Name: 207, dtype: object
# id                                395
# Contract_start    2020-06-05 00:00:00
# Contract_end      2022-02-04 00:00:00
# total_amount                    23108
# days_duration                     609
# Name: 208, dtype: object
# id                                  7
# Contract_start    2020-04-16 00:00:00
# Contract_end      2021-10-26 00:00:00
# total_amount                    22907
# days_duration                     558
# Name: 209, dtype: object
# id                                428
# Contract_start    2018-03-06 00:00:00
# Contract_end      2022-10-31 00:00:00
# total_amount                    28011
# days_duration                    1700
# Name: 210, dtype: object
# id                                 68
# Contract_start    2018-05-30 00:00:00
# Contract_end      2021-12-10 00:00:00
# total_amount                    47088
# days_duration                    1290
# Name: 211, dtype: object
# id                                286
# Contract_start    2018-10-31 00:00:00
# Contract_end      2021-07-30 00:00:00
# total_amount                     6657
# days_duration                    1003
# Name: 212, dtype: object
# id                                 72
# Contract_start    2019-08-12 00:00:00
# Contract_end      2024-10-06 00:00:00
# total_amount                    36278
# days_duration                    1882
# Name: 213, dtype: object
# id                                168
# Contract_start    2023-01-11 00:00:00
# Contract_end      2024-08-12 00:00:00
# total_amount                     2719
# days_duration                     579
# Name: 214, dtype: object
# id                                294
# Contract_start    2019-12-10 00:00:00
# Contract_end      2023-02-16 00:00:00
# total_amount                     1605
# days_duration                    1164
# Name: 215, dtype: object
# id                                482
# Contract_start    2021-10-31 00:00:00
# Contract_end      2024-07-06 00:00:00
# total_amount                    50568
# days_duration                     979
# Name: 216, dtype: object
# id                                440
# Contract_start    2017-05-31 00:00:00
# Contract_end      2020-05-25 00:00:00
# total_amount                    86759
# days_duration                    1090
# Name: 217, dtype: object
# id                                399
# Contract_start    2019-05-31 00:00:00
# Contract_end      2022-06-02 00:00:00
# total_amount                    82517
# days_duration                    1098
# Name: 218, dtype: object
# id                                349
# Contract_start    2019-12-14 00:00:00
# Contract_end      2022-06-25 00:00:00
# total_amount                    83530
# days_duration                     924
# Name: 219, dtype: object
# id                                253
# Contract_start    2023-05-21 00:00:00
# Contract_end      2023-10-25 00:00:00
# total_amount                    44816
# days_duration                     157
# Name: 220, dtype: object
# id                                486
# Contract_start    2021-12-26 00:00:00
# Contract_end      2022-11-23 00:00:00
# total_amount                    67314
# days_duration                     332
# Name: 221, dtype: object
# id                                 11
# Contract_start    2019-10-31 00:00:00
# Contract_end      2024-12-30 00:00:00
# total_amount                    63175
# days_duration                    1887
# Name: 222, dtype: object
# id                                349
# Contract_start    2021-12-11 00:00:00
# Contract_end      2024-06-28 00:00:00
# total_amount                    80761
# ...
# days_duration                    1126
# Name: 931, dtype: object
# id                                336
# Contract_start    2015-04-10 00:00:00
# Contract_end      2018-01-04 00:00:00
# total_amount                    59517
# days_duration                    1000
# Name: 932, dtype: object
# id                                453
# Contract_start    2016-08-25 00:00:00
# Contract_end      2020-03-19 00:00:00
# total_amount                    83681
# days_duration                    1302
# Name: 933, dtype: object
# id                                168
# Contract_start    2019-10-31 00:00:00
# Contract_end      2024-05-02 00:00:00
# total_amount                    10290
# days_duration                    1645
# Name: 934, dtype: object
# id                                480
# Contract_start    2017-12-28 00:00:00
# Contract_end      2020-05-24 00:00:00
# total_amount                    65051
# days_duration                     878
# Name: 935, dtype: object
# id                                418
# Contract_start    2017-08-30 00:00:00
# Contract_end      2021-01-04 00:00:00
# total_amount                    11163
# days_duration                    1223
# Name: 936, dtype: object
# id                                187
# Contract_start    2020-06-11 00:00:00
# Contract_end      2023-10-14 00:00:00
# total_amount                    56541
# days_duration                    1220
# Name: 937, dtype: object
# id                                268
# Contract_start    2021-12-30 00:00:00
# Contract_end      2024-05-10 00:00:00
# total_amount                    48525
# days_duration                     862
# Name: 938, dtype: object
# id                                210
# Contract_start    2018-12-01 00:00:00
# Contract_end      2020-01-31 00:00:00
# total_amount                    77702
# days_duration                     426
# Name: 939, dtype: object
# id                                354
# Contract_start    2016-05-11 00:00:00
# Contract_end      2022-01-02 00:00:00
# total_amount                     9427
# days_duration                    2062
# Name: 940, dtype: object
# id                                252
# Contract_start    2022-08-04 00:00:00
# Contract_end      2024-04-27 00:00:00
# total_amount                     4603
# days_duration                     632
# Name: 941, dtype: object
# id                                485
# Contract_start    2019-11-17 00:00:00
# Contract_end      2020-06-10 00:00:00
# total_amount                    10603
# days_duration                     206
# Name: 942, dtype: object
# id                                 75
# Contract_start    2019-10-30 00:00:00
# Contract_end      2024-05-18 00:00:00
# total_amount                    22311
# days_duration                    1662
# Name: 943, dtype: object
# id                                105
# Contract_start    2015-12-05 00:00:00
# Contract_end      2023-09-11 00:00:00
# total_amount                    51255
# days_duration                    2837
# Name: 944, dtype: object
# id                                147
# Contract_start    2020-12-21 00:00:00
# Contract_end      2024-08-23 00:00:00
# total_amount                    14743
# days_duration                    1341
# Name: 945, dtype: object
# id                                 39
# Contract_start    2019-02-04 00:00:00
# Contract_end      2021-02-23 00:00:00
# total_amount                    23356
# days_duration                     750
# Name: 946, dtype: object
# id                                249
# Contract_start    2020-10-30 00:00:00
# Contract_end      2022-09-30 00:00:00
# total_amount                    43891
# days_duration                     700
# Name: 947, dtype: object
# id                                209
# Contract_start    2018-02-01 00:00:00
# Contract_end      2022-06-15 00:00:00
# total_amount                    85834
# days_duration                    1595
# Name: 948, dtype: object
# id                                161
# Contract_start    2019-02-08 00:00:00
# Contract_end      2019-03-11 00:00:00
# total_amount                    31913
# days_duration                      31
# Name: 949, dtype: object
# id                                118
# Contract_start    2022-11-02 00:00:00
# Contract_end      2023-10-13 00:00:00
# total_amount                    87600
# days_duration                     345
# Name: 950, dtype: object
# id                                426
# Contract_start    2019-06-30 00:00:00
# Contract_end      2019-12-31 00:00:00
# total_amount                    89789
# days_duration                     184
# Name: 951, dtype: object
# id                                 70
# Contract_start    2018-12-26 00:00:00
# Contract_end      2023-01-10 00:00:00
# total_amount                    76273
# days_duration                    1476
# Name: 952, dtype: object
# id                                496
# Contract_start    2018-10-27 00:00:00
# Contract_end      2021-12-17 00:00:00
# total_amount                    63032
# days_duration                    1147
# Name: 953, dtype: object
# id                                171
# Contract_start    2021-12-27 00:00:00
# Contract_end      2022-04-10 00:00:00
# total_amount                    37924
# days_duration                     104
# Name: 954, dtype: object
# id                                153
# Contract_start    2017-03-05 00:00:00
# Contract_end      2021-05-10 00:00:00
# total_amount                    43999
# days_duration                    1527
# Name: 955, dtype: object
# id                                 58
# Contract_start    2019-11-11 00:00:00
# Contract_end      2024-12-31 00:00:00
# total_amount                    39661
# days_duration                    1877
# Name: 956, dtype: object
# id                                 67
# Contract_start    2017-08-30 00:00:00
# Contract_end      2020-11-11 00:00:00
# total_amount                    19343
# days_duration                    1169
# Name: 957, dtype: object
# id                                347
# Contract_start    2019-11-13 00:00:00
# Contract_end      2024-08-18 00:00:00
# total_amount                    40187
# days_duration                    1740
# Name: 958, dtype: object
# id                                314
# Contract_start    2016-06-15 00:00:00
# Contract_end      2023-03-12 00:00:00
# total_amount                    42186
# days_duration                    2461
# Name: 959, dtype: object
# id                                340
# Contract_start    2015-06-10 00:00:00
# Contract_end      2021-12-31 00:00:00
# total_amount                     4579
# days_duration                    2396
# Name: 960, dtype: object
# id                                449
# Contract_start    2021-03-04 00:00:00
# Contract_end      2021-06-03 00:00:00
# total_amount                    30287
# days_duration                      91
# Name: 961, dtype: object
# id                                354
# Contract_start    2023-01-09 00:00:00
# Contract_end      2023-10-05 00:00:00
# total_amount                    54527
# days_duration                     269
# Name: 962, dtype: object
# id                                 69
# Contract_start    2019-11-15 00:00:00
# Contract_end      2024-08-11 00:00:00
# total_amount                    42974
# days_duration                    1731
# Name: 963, dtype: object
# id                                257
# Contract_start    2020-07-16 00:00:00
# Contract_end      2023-11-05 00:00:00
# total_amount                    75696
# days_duration                    1207
# Name: 964, dtype: object
# id                                344
# Contract_start    2019-01-06 00:00:00
# Contract_end      2019-07-04 00:00:00
# total_amount                    71936
# days_duration                     179
# Name: 965, dtype: object
# id                                 67
# Contract_start    2020-10-23 00:00:00
# Contract_end      2022-07-18 00:00:00
# total_amount                    79305
# days_duration                     633
# Name: 966, dtype: object
# id                                 34
# Contract_start    2018-09-22 00:00:00
# Contract_end      2019-04-12 00:00:00
# total_amount                    46112
# days_duration                     202
# Name: 967, dtype: object
# id                                179
# Contract_start    2018-03-26 00:00:00
# Contract_end      2020-05-15 00:00:00
# total_amount                    29542
# days_duration                     781
# Name: 968, dtype: object
# id                                182
# Contract_start    2021-12-31 00:00:00
# Contract_end      2023-01-03 00:00:00
# total_amount                    66543
# days_duration                     368
# Name: 969, dtype: object
# id                                235
# Contract_start    2023-10-09 00:00:00
# Contract_end      2024-08-24 00:00:00
# total_amount                    70233
# days_duration                     320
# Name: 970, dtype: object
# id                                386
# Contract_start    2020-10-31 00:00:00
# Contract_end      2023-01-08 00:00:00
# total_amount                    40442
# days_duration                     799
# Name: 971, dtype: object
# id                                273
# Contract_start    2015-12-30 00:00:00
# Contract_end      2019-02-14 00:00:00
# total_amount                    42222
# days_duration                    1142
# Name: 972, dtype: object
# id                                268
# Contract_start    2018-11-24 00:00:00
# Contract_end      2023-04-22 00:00:00
# total_amount                    31244
# days_duration                    1610
# Name: 973, dtype: object
# id                                452
# Contract_start    2023-06-29 00:00:00
# Contract_end      2023-12-26 00:00:00
# total_amount                    43033
# days_duration                     180
# Name: 974, dtype: object
# id                                218
# Contract_start    2019-02-11 00:00:00
# Contract_end      2019-10-19 00:00:00
# total_amount                    32151
# days_duration                     250
# Name: 975, dtype: object
# id                                325
# Contract_start    2024-05-31 00:00:00
# Contract_end      2024-12-31 00:00:00
# total_amount                     2088
# days_duration                     214
# Name: 976, dtype: object
# id                                213
# Contract_start    2019-12-20 00:00:00
# Contract_end      2020-04-30 00:00:00
# total_amount                    89679
# days_duration                     132
# Name: 977, dtype: object
# id                                 99
# Contract_start    2022-01-21 00:00:00
# Contract_end      2024-12-02 00:00:00
# total_amount                    56563
# days_duration                    1046
# Name: 978, dtype: object
# id                                376
# Contract_start    2017-10-16 00:00:00
# Contract_end      2021-02-02 00:00:00
# total_amount                    35771
# days_duration                    1205
# Name: 979, dtype: object
# id                                495
# Contract_start    2016-06-11 00:00:00
# Contract_end      2020-12-19 00:00:00
# total_amount                    32955
# days_duration                    1652
# Name: 980, dtype: object
# id                                265
# Contract_start    2018-08-29 00:00:00
# Contract_end      2022-09-15 00:00:00
# total_amount                    74013
# days_duration                    1478
# Name: 981, dtype: object
# id                                373
# Contract_start    2022-12-23 00:00:00
# Contract_end      2023-12-04 00:00:00
# total_amount                    54349
# days_duration                     346
# Name: 982, dtype: object
# id                                254
# Contract_start    2019-01-11 00:00:00
# Contract_end      2020-03-07 00:00:00
# total_amount                    33896
# days_duration                     421
# Name: 983, dtype: object
# id                                 41
# Contract_start    2016-06-10 00:00:00
# Contract_end      2024-12-30 00:00:00
# total_amount                    74933
# days_duration                    3125
# Name: 984, dtype: object
# id                                 23
# Contract_start    2022-01-04 00:00:00
# Contract_end      2022-05-03 00:00:00
# total_amount                    89882
# days_duration                     119
# Name: 985, dtype: object
# id                                156
# Contract_start    2022-01-04 00:00:00
# Contract_end      2023-12-01 00:00:00
# total_amount                    76992
# days_duration                     696
# Name: 986, dtype: object
# id                                314
# Contract_start    2018-10-30 00:00:00
# Contract_end      2022-11-29 00:00:00
# total_amount                    34988
# days_duration                    1491
# Name: 987, dtype: object
# id                                151
# Contract_start    2016-07-10 00:00:00
# Contract_end      2021-06-30 00:00:00
# total_amount                    52281
# days_duration                    1816
# Name: 988, dtype: object
# id                                323
# Contract_start    2018-05-31 00:00:00
# Contract_end      2021-04-07 00:00:00
# total_amount                    65042
# days_duration                    1042
# Name: 989, dtype: object
# id                                450
# Contract_start    2023-06-30 00:00:00
# Contract_end      2023-08-31 00:00:00
# total_amount                    35019
# days_duration                      62
# Name: 990, dtype: object
# id                                229
# Contract_start    2016-11-16 00:00:00
# Contract_end      2019-12-23 00:00:00
# total_amount                    54944
# days_duration                    1132
# Name: 991, dtype: object
# id                                  9
# Contract_start    2020-05-23 00:00:00
# Contract_end      2020-05-30 00:00:00
# total_amount                     4229
# days_duration                       7
# Name: 992, dtype: object
# id                                468
# Contract_start    2022-04-14 00:00:00
# Contract_end      2024-06-12 00:00:00
# total_amount                    29982
# days_duration                     790
# Name: 993, dtype: object
# id                                307
# Contract_start    2016-12-11 00:00:00
# Contract_end      2018-04-04 00:00:00
# total_amount                    66226
# days_duration                     479
# Name: 994, dtype: object
# id                                326
# Contract_start    2016-08-15 00:00:00
# Contract_end      2024-11-26 00:00:00
# total_amount                    68398
# days_duration                    3025
# Name: 995, dtype: object
# id                                 18
# Contract_start    2021-07-31 00:00:00
# Contract_end      2024-05-18 00:00:00
# total_amount                    45222
# days_duration                    1022
# Name: 996, dtype: object
# id                                454
# Contract_start    2019-12-18 00:00:00
# Contract_end      2022-08-11 00:00:00
# total_amount                    46674
# days_duration                     967
# Name: 997, dtype: object
# id                                272
# Contract_start    2018-11-30 00:00:00
# Contract_end      2019-12-22 00:00:00
# total_amount                    17708
# days_duration                     387
# Name: 998, dtype: object
# id                                441
# Contract_start    2022-10-22 00:00:00
# Contract_end      2023-11-30 00:00:00
# total_amount                    25515
# days_duration                     404
# Name: 999, dtype: object
#       id Contract_start Contract_end  total_amount  days_duration  \
# 0    362     2021-02-28   2023-01-28         20474            699
# 1    476     2018-11-05   2024-02-08         25062           1921
# 2    318     2015-02-12   2021-01-05         24979           2154
# 3    405     2020-12-13   2023-03-13         19372            820
# 4    454     2019-10-31   2022-03-30         89682            881
# ..   ...            ...          ...           ...            ...
# 995  326     2016-08-15   2024-11-26         68398           3025
# 996   18     2021-07-31   2024-05-18         45222           1022
# 997  454     2019-12-18   2022-08-11         46674            967
# 998  272     2018-11-30   2019-12-22         17708            387
# 999  441     2022-10-22   2023-11-30         25515            404
#
#      payment_freq  payment_amount
# 0              23      890.173913
# 1              62      404.225806
# 2              69      362.014493
# 3              26      745.076923
# 4              28     3202.928571
# ..            ...             ...
# 995            98      697.938776
# 996            33     1370.363636
# 997            31     1505.612903
# 998            12     1475.666667
# 999            13     1962.692308
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Creación de csv de pagos

# %%
# Función para generar fechas de pago dentro del rango entre Contract_start y Contract_end
def generate_payment_dates(start_date, end_date, freq):
    payment_dates = []
    diference = end_date - start_date
    days = diference.days
    number_days=days/freq
    fecha_nueva=start_date
    dates=[]
    for i in range(freq):
        fecha_nueva = fecha_nueva + timedelta(days=number_days)
        dates.append(fecha_nueva)
    return dates

def is_paid(row):
    if row['payment_dates'] < today:
            status = random.choice(['make', 'miss']) 
    else:
        status = 'waiting'  
    # print(status)
    return status

payments_df = pd.DataFrame(columns=['id', 'payment_date', 'status'])
dframes=[]

# Iterar sobre cada fila del DataFrame original
for index, row in data.iterrows():
    # Generar fechas de pago
    payment_dates = generate_payment_dates(row['Contract_start'], row['Contract_end'], row['payment_freq'])
    df = pd.DataFrame({'id': row['id'], 'payment_dates':  payment_dates})
    dframes.append(df)

payments=pd.concat(dframes)
payments['status']=payments.apply(is_paid, axis=1)
payments
# Out:
#      id              payment_dates status
# 0   362 2021-03-30 09:23:28.695652   miss
# 1   362 2021-04-29 18:46:57.391304   make
# 2   362 2021-05-30 04:10:26.086956   miss
# 3   362 2021-06-29 13:33:54.782608   make
# 4   362 2021-07-29 22:57:23.478260   miss
# ..  ...                        ...    ...
# 8   441 2023-07-28 16:36:55.384614   miss
# 9   441 2023-08-28 18:27:41.538460   make
# 10  441 2023-09-28 20:18:27.692306   make
# 11  441 2023-10-29 22:09:13.846152   make
# 12  441 2023-11-29 23:59:59.999998   miss
#
# [37688 rows x 3 columns]

# %%
payments.to_csv('PAYMENT_DATA.csv', index=False)
